# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pf = pd.read_csv("titanic_train.csv")

# %%
pf1 = pd.read_csv("titanic_test.csv")

# %%
pf0 = pd.read_csv("titanic_main.csv")

# %%
pf2 = pd.concat([pf, pf1])

# %%
pf0.shape
# Out:
# (891, 12)

# %%
pf0.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
pf0.Sex.value_counts().plot(kind='bar')

# %%
pf0[pf0.Sex == "female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# ...

# %%
pf2[pf2.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Cabin, Embarked, Fare, Name, Parch, PassengerId, Pclass, Sex, SibSp, Survived, Ticket]
# Index: []

# %%
pf0.Fare.value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 26.5500     15
# 0.0000      15
# 7.2292      15
# 7.8542      13
# 8.6625      13
# 7.2500      13
# 7.2250      12
# 16.1000      9
# 9.5000       9
# 24.1500      8
# 15.5000      8
# 56.4958      7
# 52.0000      7
# 14.5000      7
# 14.4542      7
# 69.5500      7
# 7.0500       7
# 31.2750      7
# 46.9000      6
# 30.0000      6
# 7.7958       6
# 39.6875      6
#             ..
# 7.1417       1
# 42.4000      1
# 211.5000     1
# 12.2750      1
# 61.1750      1
# 8.4333       1
# 51.4792      1
# 7.8875       1
# 8.6833       1
# 7.5208       1
# 34.6542      1
# 28.7125      1
# 25.5875      1
# 7.7292       1
# 12.2875      1
# 8.6542       1
# 8.7125       1
# 61.3792      1
# 6.9500       1
# 9.8417       1
# 8.3000       1
# 13.7917      1
# 9.4750       1
# 13.4167      1
# 26.3875      1
# 8.4583       1
# 9.8375       1
# ...

# %%
pf0.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
pf0.Fare.hist(bins=5)

# %%
pf0[pf0.Fare.isnull()]
# Out:
#       Age Cabin Embarked  Fare                Name  Parch  PassengerId  \
# 152  60.5   NaN        S   NaN  Storey, Mr. Thomas      0         1044
#
#      Pclass   Sex  SibSp  Survived Ticket
# 152       3  male      0       NaN   3701

# %%
pf2[pf2.Fare == 0]
# Out:
#       Age        Cabin Embarked  Fare                                   Name  \
# 179  36.0          NaN        S   0.0                    Leonard, Mr. Lionel
# 263  40.0          B94        S   0.0                  Harrison, Mr. William
# 271  25.0          NaN        S   0.0           Tornquist, Mr. William Henry
# 277   NaN          NaN        S   0.0            Parkes, Mr. Francis "Frank"
# 302  19.0          NaN        S   0.0        Johnson, Mr. William Cahoone Jr
# 413   NaN          NaN        S   0.0         Cunningham, Mr. Alfred Fleming
# 466   NaN          NaN        S   0.0                  Campbell, Mr. William
# 481   NaN          NaN        S   0.0       Frost, Mr. Anthony Wood "Archie"
# 597  49.0          NaN        S   0.0                    Johnson, Mr. Alfred
# 633   NaN          NaN        S   0.0          Parr, Mr. William Henry Marsh
# 674   NaN          NaN        S   0.0             Watson, Mr. Ennis Hastings
# ...

# %%
fig, axs = plt.subplots(1, 2)
pf0[pf0.Sex=='male'].Survived.value_counts().plot(kind='barh', ax=axs[0])
pf0[pf0.Sex=='female'].Survived.value_counts().plot(kind='barh', ax=axs[1])

# %%
pf0[pf0.Age < 15].Survived.value_counts().plot(kind='bar')

# %%
pf0[(pf0.Age < 15) & (pf0.Sex == 'male')].Survived.value_counts().plot(kind='bar')

# %%
pf0.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
342/pf0.shape[0]
# Out:
# 0.3838383838383838

# %%
pf0[pf0.Pclass == 1].Pclass.value_counts()
# Out:
# 1    216
# Name: Pclass, dtype: int64

# %%
216/pf0.shape[0]
# Out:
# 0.24242424242424243

# %%
 from numpy import median

# %%
median(pf0[(pf0.Age > 0) & (pf0.Age < 100)].Age)
# Out:
# 28.0

# %%
average(pf0[(pf0.Age > 0) & (pf0.Age < 100)].Age)
# Out:
# 29.69911764705882

# %%
fn = pf0[pf0['Sex'] == 'female']['Name']
import re 
def extract_first_name(name):
    """
    Функция извлечения first name from name
    :param name: name
    :return: first name
    """
    # первое слово в скобках
    m = re.search(".*\\((.*)\\).*", name)
    if m is not None:
        return m.group(1).split(" ")[0]
    # первое слово после Mrs. or Miss. or else
    m1 = re.search(".*\\. ([A-Za-z]*)", name)
    return m1.group(1)

# получаем имя с максимальной частотой
r = fn.map(lambda full_name: extract_first_name(full_name)).value_counts()
print(r)
# Out:
# Anna         15
# Mary         14
# Elizabeth    11
# Margaret     10
# Alice         6
# Helen         5
# Bertha        5
# Maria         4
# "Mrs          4
# Marion        4
# Ellen         4
# Catherine     4
# Augusta       4
# Florence      4
# Marie         4
# Annie         4
# Emily         4
# Ada           4
# Katherine     3
# Ida           3
# Edith         3
# Lillian       3
# Madeleine     3
# Jane          3
# Hanora        3
# Elisabeth     3
# Amelia        3
# Lucy          2
# Emma          2
# Marija        2
#              ..
# Joan          1
# Helena        1
# Ingeborg      1
# Elna          1
# Helmina       1
# Katriina      1
# Elin          1
# Vera          1
# Ruth          1
# Hildur        1
# Emelia        1
# Matilda       1
# Margit        1
# Gretchen      1
# Amelie        1
# Mari          1
# Lutie         1
# Erna          1
# Miriam        1
# Bessie        1
# Delia         1
# Edwina        1
# Hulda         1
# Edwiga        1
# ...

# %%
corr = round(pf0['SibSp'].corr(pf0['Parch']), 2)
print(corr)
# Out:
# 0.41

# %%
y = pf0['Survived']

# %%
def convert_sex(sex):
    if sex == 'male':
        return 1
    else:
        return 0

# %%
X = pf0.loc[:,['Sex','Pclass', 'Fare', 'Age']]

# %%
X
# Out:
#         Sex  Pclass      Fare   Age
# 0      male       3    7.2500  22.0
# 1    female       1   71.2833  38.0
# 2    female       3    7.9250  26.0
# 3    female       1   53.1000  35.0
# 4      male       3    8.0500  35.0
# 5      male       3    8.4583   NaN
# 6      male       1   51.8625  54.0
# 7      male       3   21.0750   2.0
# 8    female       3   11.1333  27.0
# 9    female       2   30.0708  14.0
# 10   female       3   16.7000   4.0
# 11   female       1   26.5500  58.0
# 12     male       3    8.0500  20.0
# 13     male       3   31.2750  39.0
# 14   female       3    7.8542  14.0
# 15   female       2   16.0000  55.0
# 16     male       3   29.1250   2.0
# 17     male       2   13.0000   NaN
# 18   female       3   18.0000  31.0
# 19   female       3    7.2250   NaN
# 20     male       2   26.0000  35.0
# 21     male       2   13.0000  34.0
# 22   female       3    8.0292  15.0
# 23     male       1   35.5000  28.0
# 24   female       3   21.0750   8.0
# ...

# %%
X['Sex'] = X['Sex'].apply(convert_sex)

# %%
X = X.drop(X[X.Age.isnull()].index)

# %%
y = y.drop(pf0[pf0.Age.isnull()].index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-190-700d9c3196e3> in <module>()
# ----> 1 y = y.drop(pf0[pf0.Age.isnull()].index)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()
clf.fit(X, y)

# %%
importances = clf.feature_importances_

# %%
importances
